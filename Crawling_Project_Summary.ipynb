# %% [markdown]
# # 데이터 크롤링 프로젝트

# %%
from IPython.display import Image

# %% [markdown]
# ## 1. 데이터 수집의 개요

# %% [markdown]
# - 1) 문제 상황 : "콜라보 상품 정보는 제한 되어있어서 쉽게 접하기 어렵다."
# - 2) 수집동기 : "접하기 힘든 콜라보 상품의 정보를 수집한다."

# %% [markdown]
# ## 2. 데이터 수집의 계획 및 주기 작성
# - 1) HYPEBEAST : 세계적인 패션과 스트릿 웨어 뉴스 웹 매거진
#     - url : "https://hypebeast.kr/"
# - 2) 데이터 수집 대상 : 패션, 신발, 음악, 미술, 디자인 등 최신 뉴스 기사 크롤링
# - 3) 데이터 수집 주기 : 매일 한 번씩 크롤링
# - 4) 데이터 베이스 : MongoDB 에 컬렉션 생성 후 데이터 저장
# - 5) 데이터 처리 : 뉴스 기사에서 콜라보와 협업 키워드를 설정하여, 발매일자와 발매장소정보를 추출

# %%
Image("hy_main.png")

# %%
Image("hblogo_1.jpg")

# %%
Image("nike_dior.png")

# %% [markdown]
# ## 3. 크롤링 방법
# - get url
# - response, requests -> Html
# - beautifulSuop obj -> dict 파싱
# - cloumns = category, title, summary, author, link, date, content
# - class obj record : Hypebeast.py

# %% [markdown]
# ## 4. 데이터의 저장
# - ubuntu server
# - import Hypebeast.py
# - MongoDB record

# %% [markdown]
# ## 5. 프로젝트 회고
# - 결론 :
#     - 다양한 브랜드의 콜라보 및 협업 제품의 발매 기사가 지속적으로 업데이트 되고 있었음.
#     - 네이버, 다음 포탈의 블로그나 포스트 보다 해당 기사에 구체적인 발매 정보를 확인 할 수 있었음.
# - 추후 연구 및 개선 사항 :
#     - 카테고리 임베딩을 적용하여 데이터를 분석하고, 본문에서 특정 키워드를 추출해보면 좋을 것 같다.
#     - 추출
