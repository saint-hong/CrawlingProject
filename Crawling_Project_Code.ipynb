# %%
import requests
from bs4 import BeautifulSoup

# %%
elements = []
for page in range(1, 5):
    print("Crawling : {}".format(page))
    url = "https://hypebeast.kr/page/{}?after=".format(page)

    response = requests.get(url)
    response

    response.text

    dom = BeautifulSoup(response.content, "html.parser")
    type(dom)

    elements = elements + dom.select(".posts>div>.post-box-content-container")
len(elements)
# Out:
# 1 페이지 읽는중...
# 2 페이지 읽는중...
# 3 페이지 읽는중...
# 4 페이지 읽는중...
# 40

# %%
elements[0]
# Out:
# <div class="post-box-content-container"><div class="post-box-content-categories"><a class="category category-footwear" ga-event-action="clicks_category" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/footwear" ga-on="click" href="https://hypebeast.kr/footwear" title="신발">신발</a></div><div class="post-box-content-title"><a class="title" ga-event-action="clicks_article_title" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/3/shawn-stussy-dior-b23-collaboration-sneakers-image" ga-on="click" href="https://hypebeast.kr/2020/3/shawn-stussy-dior-b23-collaboration-sneakers-image" title="숀 스투시의 아트워크가 새겨진, 디올 ‘B23’ 협업 스니커 실물 이미지 공개"><h2><span>숀 스투시의 아트워크가 새겨진, 디올 ‘B23’ 협업 스니커 실물 이미지 공개</span></h2></a></div><div class="post-box-content-excerpt">
#                                 숀 스투시의 아트워크 &amp; 디올 오블리크 패턴.
#                         </div><div class="post-box-content-meta"><div class="post-box-meta-author-time"><span class="author"><span class="author-name">By <a class="article-author" ga-event-action="clicks_author" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/3/shawn-stussy-dior-b23-collaboration-sneakers-image" ga-on="click" href="https://hypebeast.kr/author/hyeonuk" rel="author">Hyeonuk Joo</a></span></span><span class="divider">/</span><span class="time"><time class="timeago" datetime="2020-03-18T06:41:24Z">36 seconds ago</time></span></div><div class="post-box-content-meta-time-info"><span class="time"><time class="timeago" datetime="2020-03-18T06:41:24Z">36 seconds ago</time></span><div class="post-box-stats"><span class="divider">  </span><span class="comment-count"></span></div></div></div></div>

# %%
datas = []

for element in elements :
    try:
        category = element.select_one('.post-box-content-categories> a').text
    except:
        category = "-"
    try:
        title = element.select_one('.post-box-content-title > a').text
    except:
        title = "-"
    try:
        summary = element.select_one('.post-box-content-excerpt').text.strip()
    except:
        summary = "-"
    try:
        author = element.select_one('.author-name > a').text
    except:
        author = "-"
    try:
        link = element.select_one('.post-box-content-title > a').get("href")
    except:
        link = "-"
    try:
        date = element.select_one('.time > time').text
    except:
        date = "-"
        
    datas.append({
        "category" : category,
        "title" : title,
        "summary" : summary,
        "author" : author,
        "link" : link,
        "date" : date,
    })
hb_df = pd.DataFrame(datas)
hb_df.tail()
# Out:
#    category                                           title  \
# 35       신발                 꼼 데 가르송과 나이키의 새 협업 덩크 로우, 실물 공개
# 36       패션             나이키, 코로나19 확산 방지 위해 미국 내 전 매장 휴업 조치
# 37       패션  베이프의 세컨드 라인업, 에이프 x 알파 인더스트리 캡슐 컬렉션 룩북 및 발매 정보
# 38       전자                     빌 게이츠, 마이크로소프트 이사직 최종 사임 결정
# 39       패션                 팔라스의 2020 봄 컬렉션 여섯 번째 드롭 리스트 공개
#
#                      summary         author  \
# 35                  종류는 2가지.     Soobin Kim
# 36    슈프림, 팔라스도 임시 휴업에 들어갔다.  Yonghwan Choi
# 37  에이프 유인원 로고가 새겨진 MA-1 재킷.    Hyeonuk Joo
# 38    자선사업 빛 전염병 퇴치에 전념할 예정.  Seung Ho Jang
# 39         봄에는 후디에 반바지가 딱이지.     Eunbo Shim
#
#                                                  link          date
# 35  https://hypebeast.kr/2019/9/comme-des-garcons-...  Mar 16, 2020
# 36  https://hypebeast.kr/2020/3/nike-shut-down-all...  Mar 16, 2020
# 37  https://hypebeast.kr/2020/3/alpha-industries-a...  Mar 16, 2020
# 38  https://hypebeast.kr/2020/3/bill-gates-microso...  Mar 16, 2020
# 39  https://hypebeast.kr/2020/3/palace-skateboards...  Mar 16, 2020

# %%
hb_df.loc[0, "link"]
# Out:
# 'https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases'

# %% [markdown]
# ### content 데이터 추가하기

# %%
link = hb_df.loc[0, "link"]
link
# Out:
# 'https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases'

# %%
response = requests.get(link)
response
# Out:
# <Response [200]>

# %%
print(link)
# Out:
# https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases

# %%
dom = BeautifulSoup(response.content, "html.parser")
type(dom)
# Out:
# bs4.BeautifulSoup

# %%
dom
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <script type="text/javascript">
#             var themeCookie = 'light';
#
#             var cookieName = 'hb-theme';
#
#             if (window.matchMedia('(prefers-color-scheme: dark)').matches) {
#                 themeCookie = 'dark';
#             } else if (window.matchMedia('(prefers-color-scheme: light)').matches) {
#                 themeCookie = 'light';
#             }
#
#             var cookiearray = document.cookie.split(';');
#
#             // Now take key value pair out of this array
#             if (document.cookie) {
#                 for (var i = 0; i < cookiearray.length; i++) {
#                     var name = cookiearray[i].split('=')[0].trim();
#                     var value = cookiearray[i].split('=')[1].trim();
#
#                     if (name === cookieName) {
#                         themeCookie = value;
#                     }
#                 }
#             }
#
#             function SetDarkMode() {
#                 if (themeCookie) {
#                     document.querySelector('html').setAttribute('data-theme', themeCookie);
#                 }
#             }
#
#             SetDarkMode();
#
#             // document.querySelector('html').setAttribute('data-theme', 'light');
#
#         </script>
# <meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no, shrink-to-fit=no" name="viewport"/><title>애플 비츠 바이 드레 파워비츠4 공식 발매 정보 및 가격, 비츠 바이 드레, 애플 | HYPEBEAST.KR | 하입비스트</title><meta content="애플, 비츠 바이 드레 파워비츠 4 공식 발매 정보 및 가격: 루머가 전부 들어맞았다." name="description"><link href="https://static.hypebeast.com/dist/styles/font-kr.css?j89547yv" rel="stylesheet"/><link href="https://static.hypebeast.com/dist/styles/hypebeast.css?j89547yv" rel="stylesheet"/><link href="https://static.hypebeast.com/dist/hypebeast/sprite.css?j89547yv" rel="preload"/><link href="https://static.hypebeast.com/dist/styles/hypebeast-post.css?j89547yv" rel="stylesheet"/><script type="text/javascript">
#                 var hypebeast = hypebeast || {};
#                                 hypebeast.dfpID = '1015938';
#                                 hypebeast.hypebeastLogUrl = 'https://log.hypebeast.com/v1/systems/hypebeast/batchEvents/';
#                 hypebeast.hypebeastLogRegion = 'kr';
#                 hypebeast.siteName = 'HYPEBEAST.KR | 하입비스트';
#                 hypebeast.ajaxNativeAdUrl = 'https://hypebeast.kr/_ajax/native-ad';
#                 hypebeast.ajaxNativeSponsorAdUrl = 'https://hypebeast.kr/_ajax/native-sponsor-ad';
#                 hypebeast.registerSuccessUrl = 'https://hypebeast.kr/register/success';
#                 hypebeast.searchUrl = 'https://hypebeast.kr/search';
#             </script><script type="application/ld+json">
#             {
#                 "@context" : "http://schema.org",
#                 "@type" : "Organization",
#                 "url" : "https://hypebeast.kr/",
#                 "logo" : "https://static.hypebeast.com/images/hypebeast/logo.png?j89547yv",
#                 "sameAs" : [
#                     "https://www.facebook.com/hypebeastkr",
#                     "https://www.twitter.com/hypebeast",
#                     "https://www.instagram.com/hypebeastkr",
#                     "https://www.youtube.com/HypebeastTV",
#                     "https://itunes.apple.com/app/hypebeast/id986768161",
#                     "https://play.google.com/store/apps/details?id=com.hypebeast.editorial"
#                 ],
#                 "founder": "Kevin Ma",
#                 "foundingDate": "2005",
#                 "legalName": "Hypebeast Hong Kong Limited",
#                 "location": {
#                     "@type": "Place",
#                     "address": {
#                         "@type": "PostalAddress",
#                         "addressLocality": "Hypebeast Hong Kong Limited, 10/F, KC100, 100 Kwai Cheong Road, Kwai Chung, Hong Kong"
#                     }
#                 },
#                 "telephone": "+852 3563 9035"
#             }
#             </script><meta content="fa9445c4c9e6dfcded331f9c6cb9d44979334bd7" name="naver-site-verification"><script src="//developers.kakao.com/sdk/js/kakao.min.js"></script><script>
#                 dataLayer = window.dataLayer || [];
#                 dataLayer.push({ 'userRegion': 'AMER' });
#                 dataLayer.push({ 'consent': (document.cookie.match('(^|; )' + 'OptanonAlertBoxClosed' + '=([^;]*)') || 0)[2] ? 'yes' : 'no' });
#                             </script><script>
#         dataLayer = window.dataLayer || [];
#         dataLayer.push({ 'pageType': 'post' });
#         dataLayer.push({ 'postId': 'kr265611' });
#     </script><!-- Rakuten --><script>
#                 dataLayer = window.dataLayer || [];
#         dataLayer.push({ 'Rakutenkey' : 'automate_hbkr_web_organic_article:265611' });
#         dataLayer.push({ 'RakutenApply': 'true' });
#             </script><script>
#                 dataLayer = window.dataLayer || [];
#         dataLayer.push({'pageType': 'post'});
#         dataLayer.push({'postId': 'kr265611'});
#             </script><!-- Google Tag Manager --><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-68NN" style="display:none;visibility:hidden" width="0"></iframe></noscript><script>(function (w, d, s, l, i) {
#                     w[l] = w[l] || [];
#                     w[l].push({
#                         'gtm.start':
#                             new Date().getTime(), event: 'gtm.js'
#                     });
#                     var f = d.getElementsByTagName(s)[0],
#                         j = d.createElement(s),
#                         dl = l != 'dataLayer' ? '&l=' + l : '';
#                     j.async = true;
#                     j.src =
#                         '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#                     f.parentNode.insertBefore(j, f);
#                 })(window, document, 'script', 'dataLayer', 'GTM-68NN');
#             </script><!-- End Google Tag Manager --><!-- Google Analytics --><script>
#                 (function (i, s, o, g, r, a, m) {
#                     i['GoogleAnalyticsObject'] = r;
#                     i[r] = i[r] || function () {
#                         (i[r].q = i[r].q || []).push(arguments);
#                     }, i[r].l = 1 * new Date();
#                     a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                     a.async = 1;
#                     a.src = g;
#                     m.parentNode.insertBefore(a, m);
#                 })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#                                                 ga('create', 'UA-546583-1', 'auto', { 'useAmpClientId': true });
#                 ga('require', 'GTM-MSNGKV9');
#                 ga('require', 'displayfeatures');
#                 ga('require', 'eventTracker');
#                 ga('require', 'impressionTracker', {"attributePrefix":"ga-impression-"});
#                                 ga('send', 'pageview', {'dimension3':'March', 'dimension4':'2020', 'dimension5':'Eunbo Shim', 'dimension6':'전자', 'dimension7':'18', 'dimension15': '265611'});
#                             </script><!-- End Google Analytics --><!-- Page hiding snippet (recommended)  --><style>.async-hide {
#                     opacity: 0 !important
#                 } </style><script>(function (a, s, y, n, c, h, i, d, e) {
#                     s.className += ' ' + y;
#                     h.start = 1 * new Date;
#                     h.end = i = function () {
#                         s.className = s.className.replace(RegExp(' ?' + y), '');
#                     };
#                     (a[n] = a[n] || []).hide = h;
#                     setTimeout(function () {
#                         i();
#                         h.end = null;
#                     }, c);
#                     h.timeout = c;
#                 })(window, document.documentElement, 'async-hide', 'dataLayer', 4000,
#                     { 'GTM-MSNGKV9': true });</script><script type="text/javascript">
#                 // Register Facebook callback
#                 window.fbAsyncInit = function () {
#                     FB.init({
#                         appId: 190339178174576,
#                         status: true,
#                         xfbml: true,
#                         version: 'v2.10'
#                     });
#                 };
#             </script>
# <meta content="190339178174576" property="fb:app_id"/>
# <meta content="10862404186,317794296932,373577572727153,675268962502985,1037470986391901,324555257962235,898679466908196,137598866658599,191202487943746,1749452888713309" property="fb:pages"/>
# <link href="https://static.hypebeast.com/images/hypebeast/favicon/favicon.ico?j89547yv" rel="icon" type="image/x-icon"/>
# <link href="https://static.hypebeast.com/images/hypebeast/favicon/apple-icon-120x120.png?j89547yv" rel="apple-touch-icon"/>
# <link href="https://static.hypebeast.com/images/hypebeast/favicon/apple-icon-152x152.png?j89547yv" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://static.hypebeast.com/images/hypebeast/favicon/apple-icon-180x180.png?j89547yv" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://static.hypebeast.com/images/hypebeast/favicon/android-icon-192x192.png?j89547yv" rel="icon" sizes="192x192"/>
# <link href="https://static.hypebeast.com/manifest.json?j89547yv" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="https://static.hypebeast.com/images/hypebeast/favicon/android-icon-192x192.png?j89547yv" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="애플,에어팟,비츠 바이 드레" name="news_keywords">
# <script type="text/javascript">
#         hypebeast.firebaseServiceWorkerUrl = '/firebase-messaging-sw.js?j89547yv';
#         hypebeast.firebaseSubscribeUrl = 'https://hypebeast.kr/firebase-subscribe';
#         hypebeast.firebaseConfig = {"messagingSenderId":"438709611408"};
#         hypebeast.firebaseVAPID = 'BHow_6ysEDZAvfQGt_GGhX7FB9LLDysN4ouhd91lUxeD7eHMEpWH6JatF-xexZunANRlGq-s2feHvrcuoyygfiQ';
#         hypebeast.facebookOauthUrl = "https://hypebeast.kr/login/facebook";
#         hypebeast.systemName = 'hypebeast';
#         hypebeast.token = '';
#     </script>
# <!-- OneTrust Cookies Consent Notice start -->
# <script charset="UTF-8" data-domain-script="4396711e-5fdf-42f4-99b5-af36bc5bed8b" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
#         function OptanonWrapper() {
#         }
#     </script>
# <!-- OneTrust Cookies Consent Notice end -->
# <meta content="애플, 비츠 바이 드레 파워비츠 4 공식 발매 정보 및 가격" property="og:title">
# <meta content="https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases" property="og:url">
# <meta content="루머가 전부 들어맞았다." property="og:description"/>
# <meta content="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-powerbeats-4-releases-tw.jpg?w=960&amp;cbr=1&amp;q=90&amp;fit=max" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="HYPEBEAST.KR | 하입비스트" property="og:site_name"/>
# <link href="https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases?amp=1" rel="amphtml"/>
# <link href="https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases" rel="canonical"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@hypebeast" name="twitter:site">
# <meta content="@hypebeast" name="twitter:creator"/>
# <meta content="애플, 비츠 바이 드레 파워비츠 4 공식 발매 정보 및 가격" name="twitter:title"/>
# <meta content="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-powerbeats-4-releases-tw.jpg?w=960&amp;cbr=1&amp;q=90&amp;fit=max" name="twitter:image"/>
# <meta content="https://hypebeast.kr/" name="twitter:domain">
# <script>
#         var hypebeast = hypebeast || {};
#         hypebeast.ajaxurlPoll = "https://hypebeast.kr/_ajax/poll";
#     </script>
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "NewsArticle",
#         "mainEntityOfPage": {
#             "@type":"WebPage",
#             "@id":"https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases"
#         },
#         "headline": "애플, 비츠 바이 드레 파워비츠 4 공식 발매 정보 및 가격",
#         "datePublished": "2020-03-18T03:51:43Z",
#         "dateModified": "2020-03-18T03:52:18Z",
#         "publisher": {
#             "@type": "Organization",
#             "name": "HYPEBEAST",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": "https://static.hypebeast.com/images/hypebeast/logo.png?j89547yv"
#             }
#         },
#         "author": {
#             "@type": "Person",
#             "name": "Eunbo Shim"
#         },
#         "image": {
#             "@type": "ImageObject",
#             "url": "https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-powerbeats-4-releases-00.jpg?w=960&cbr=1&q=90&fit=max",
#             "height": 640,
#             "width": 960
#         }
#     }
# </script> </meta></meta></meta></meta></meta></meta></meta></head>
# <body class="editorial_post env-prod locale-kr post-page" data-locale="kr">
# <div id="root">
# <div class="leaderboard-wrapper top-unit">
# <div class="inner-container">
# <div class="inner-content">
# <div class="prod adunit leaderboard page- lazy-load" data-adunit="Hypebeast_KR_ROS_Top_728x90" data-dimensions="100x100,320x100,728x90,970x250,300x250,320x50,1600x400,800x400,400x200" data-size-mapping="leaderboard-top" data-sortable="true" data-targeting='{"HBSiteLoc":["ros","article"],"HBSiteCat":["tech","apple","airpod","beats-by-dre"],"HBSitePage":"0","HBSiteLang":"kr","country":"us","region":"amer","HBArticle":"265611","HBBlacklist":"0","adPosition":"top","sortable":"true"}'></div>
# </div>
# </div>
# </div>
# <header id="page-header">
# <div class="switch" id="header-wrapper"><div class="container-fluid switch" id="main-header"><div class="hamburger d-md-none" ga-event-action="clicks_burger_icon" ga-event-category="burger menu" ga-on="click"><a href="#" id="mobile-menu-toggle"><span class="sprite sprite-hamburger"></span></a></div><div class="logo"><a href="https://hypebeast.kr/"><img alt="HYPEBEAST" class="img-fluid" src="https://static.hypebeast.com/images/hypebeast2018/hypebeast-logo.svg?j89547yv"/></a></div><div class="categories"><ul class="nav main" itemscope="" itemtype="http://www.schema.org/SiteNavigationElement"><li class="category d-none d-md-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/fashion" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/fashion" itemprop="url" title="FASHION">패션</a></li><li class="category d-none d-md-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/footwear" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/footwear" itemprop="url" title="FOOTWEAR">신발</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/music" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/music" itemprop="url" title="MUSIC">음악</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/arts" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/arts" itemprop="url" title="ARTS">미술</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/design" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/design" itemprop="url" title="DESIGN">디자인</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/editorial" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/editorial" itemprop="url" title="EDITORIAL">에디토리얼</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/tech" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/tech" itemprop="url" title="TECH">전자</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/entertainment" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/entertainment" itemprop="url" title="ENTERTAINMENT">엔터테인먼트</a></li><li class="category d-none d-lg-inline nav-item" ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/automotive" ga-on="click" itemprop="name"><a href="https://hypebeast.kr/automotive" itemprop="url" title="AUTOMOTIVE">자동차</a></li><li class="category dropdown more-section d-none d-md-inline nav-item"><a class="d-flex align-items-center" href="#"><span class="sprite sprite-more-menu"></span></a><ul class="header-dropdown-menu more-section-menu"><li class="categories dropdown-item"><ul><li ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/music" ga-on="click"><a class="d-block d-lg-none" href="https://hypebeast.kr/music" title="Music">음악</a></li><li ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/arts" ga-on="click"><a class="d-block d-lg-none" href="https://hypebeast.kr/arts" title="Arts">미술</a></li><li ga-event-action="clicks_category" ga-event-category="navigation bar" ga-event-label="https://hypebeast.kr/design" ga-on="click"><a class="d-block d-lg-none" href="https://hypebeast.kr/design" title="Design">디자인</a ...
# <div id="page-header-sticky-position"></div>
# <div class="post-container post-status-publish" data-next-post-url="https://hypebeast.kr/2020/3/the-north-face-japan-urban-exploration-spring-summer-2020-collection-campaign" data-post-hypes="73" data-post-hypes-color="sprite-hype-flame-grey" data-post-id="265611" data-post-page-title="애플 비츠 바이 드레 파워비츠4 공식 발매 정보 및 가격, 비츠 바이 드레, 애플 | HYPEBEAST.KR | 하입비스트" data-post-social-thumbnail="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-powerbeats-4-releases-tw.jpg?w=960&amp;cbr=1&amp;q=90&amp;fit=max" data-post-title="애플, 비츠 바이 드레 파워비츠 4 공식 발매 정보 및 가격" data-post-url="https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases" id="post-265611">
# <section class="post">
# <div class="post-upper" id="post-upper">
# <div class="container-fluid">
# <header class="post-header text-center">
# <h1 class="post-body-title">
# <span>애플, 비츠 바이 드레 파워비츠 4 공식 발매 정보 및 가격</span>
# </h1>
# <h2 class="post-body-excerpt">
#                                             루머가 전부 들어맞았다.
#                                     </h2>
# <span class="post-body-header-author">
# <span class="author-name">By <a class="article-author" ga-event-action="clicks_author" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases" ga-on="click" href="https://hypebeast.kr/author/eunboshim" rel="author">Eunbo Shim</a></span>
# </span>
# </header>
# </div>
# </div>
# <div class="container-fluid post-lower">
# <div class="row">
# <div class="col-post-body col">
# <div class="post-gallery-container small inner-media">
# <div class="gallery-container post-gallery-contain">
# <div class="hb-gallery before-booted full-screen-enabled" data-images='[{"annotations":null,"width":1250,"height":833,"caption":null,"description":null,"credit":"Beats","src":"https:\/\/kr.hypebeast.com\/files\/2020\/03\/apple-beats-by-dre-powerbeats-4-releases-01.jpg","alt":"\uc560\ud50c \ube44\uce20 \ubc14\uc774 \ub4dc\ub808 \ud30c\uc6cc\ube44\uce204 \uacf5\uc2dd \ubc1c\ub9e4 \uc815\ubcf4 \ubc0f \uac00\uaca9, \ube44\uce20 \ubc14\uc774 \ub4dc\ub808, \uc560\ud50c, \uc774\uc5b4\ud3f0, \uc560\ud50c \uc774\uc5b4\ud3f0, \ube14\ub8e8\ud22c\uc2a4 \uc774\uc5b4\ud3f0","creditKey":"general"},{"annotations":null,"width":1250,"height":833,"caption":null,"description":null,"credit":"Beats","src":"https:\/\/kr.hypebeast.com\/files\/2020\/03\/apple-beats-by-dre-powerbeats-4-releases-02.jpg","alt":"\uc560\ud50c \ube44\uce20 \ubc14\uc774 \ub4dc\ub808 \ud30c\uc6cc\ube44\uce204 \uacf5\uc2dd \ubc1c\ub9e4 \uc815\ubcf4 \ubc0f \uac00\uaca9, \ube44\uce20 \ubc14\uc774 \ub4dc\ub808, \uc560\ud50c, \uc774\uc5b4\ud3f0, \uc560\ud50c \uc774\uc5b4\ud3f0, \ube14\ub8e8\ud22c\uc2a4 \uc774\uc5b4\ud3f0","creditKey":"general"},{"annotations":null,"width":1250,"height":833,"caption":null,"description":null,"credit":"Beats","src":"https:\/\/kr.hypebeast.com\/files\/2020\/03\/apple-beats-by-dre-powerbeats-4-releases-03.jpg","alt":"\uc560\ud50c \ube44\uce20 \ubc14\uc774 \ub4dc\ub808 \ud30c\uc6cc\ube44\uce204 \uacf5\uc2dd \ubc1c\ub9e4 \uc815\ubcf4 \ubc0f \uac00\uaca9, \ube44\uce20 \ubc14\uc774 \ub4dc\ub808, \uc560\ud50c, \uc774\uc5b4\ud3f0, \uc560\ud50c \uc774\uc5b4\ud3f0, \ube14\ub8e8\ud22c\uc2a4 \uc774\uc5b4\ud3f0","creditKey":"general"},{"annotations":null,"width":1250,"height":833,"caption":null,"description":null,"credit":"Beats","src":"https:\/\/kr.hypebeast.com\/files\/2020\/03\/apple-beats-by-dre-powerbeats-4-releases-04.jpg","alt":"\uc560\ud50c \ube44\uce20 \ubc14\uc774 \ub4dc\ub808 \ud30c\uc6cc\ube44\uce204 \uacf5\uc2dd \ubc1c\ub9e4 \uc815\ubcf4 \ubc0f \uac00\uaca9, \ube44\uce20 \ubc14\uc774 \ub4dc\ub808, \uc560\ud50c, \uc774\uc5b4\ud3f0, \uc560\ud50c \uc774\uc5b4\ud3f0, \ube14\ub8e8\ud22c\uc2a4 \uc774\uc5b4\ud3f0","creditKey":"general"}]'>
# <div class="carousel-cell landscape" data-gallery-index="1">
# <div class="carousel-cell-inner-wrapper">
# <div class="carousel-cell-image-wrapper annotation-container fixed-ratio-3-2">
# <picture>
# <source media="(min-width: 1200px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=90&amp;w=1400&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 992px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=80&amp;w=1000&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 768px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 768px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=70&amp;w=1125&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 768px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=75&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 320px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 320px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=70&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 320px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=70&amp;w=500&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 0px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 0px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=70&amp;w=480&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 0px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=70&amp;w=320&amp;cbr=1&amp;fit=max"/>
# <img alt="애플 비츠 바이 드레 파워비츠4 공식 발매 정보 및 가격, 비츠 바이 드레, 애플, 이어폰, 애플 이어폰, 블루투스 이어폰" class="carousel-cell-image" draggable="false" src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-01.jpg?q=75&amp;w=800&amp;cbr=1&amp;fit=max">
# </img></picture>
# </div>
# <span class="gallery-image-index"><span class="image-index">1 of 4</span><span class="sprite-gallery-expand" ga-event-action="clicks_fullscreen" ga-event-category="gallery post (article page)" ga-event-label="Clicks" ga-on="click"></span></span>
# <div class="gallery-meta-container credit-wrapper">
# <div class="spacer"></div>
# <div class="credit general-general">Beats</div>
# </div>
# </div>
# </div>
# <div class="carousel-cell landscape" data-gallery-index="2">
# <div class="carousel-cell-inner-wrapper">
# <div class="carousel-cell-image-wrapper annotation-container fixed-ratio-3-2">
# <picture>
# <source media="(min-width: 1200px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=90&amp;w=1400&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 992px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=80&amp;w=1000&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 768px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 768px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=70&amp;w=1125&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 768px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=75&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 320px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 320px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=70&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 320px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=70&amp;w=500&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 0px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 0px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=70&amp;w=480&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 0px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=70&amp;w=320&amp;cbr=1&amp;fit=max"/>
# <img alt="애플 비츠 바이 드레 파워비츠4 공식 발매 정보 및 가격, 비츠 바이 드레, 애플, 이어폰, 애플 이어폰, 블루투스 이어폰" class="carousel-cell-image" draggable="false" src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-02.jpg?q=75&amp;w=800&amp;cbr=1&amp;fit=max"/>
# </picture>
# </div>
# <span class="gallery-image-index"><span class="image-index">2 of 4</span><span class="sprite-gallery-expand" ga-event-action="clicks_fullscreen" ga-event-category="gallery post (article page)" ga-event-label="Clicks" ga-on="click"></span></span>
# <div class="gallery-meta-container credit-wrapper">
# <div class="spacer"></div>
# <div class="credit general-general">Beats</div>
# </div>
# </div>
# </div>
# <div class="carousel-cell landscape" data-gallery-index="3">
# <div class="carousel-cell-inner-wrapper">
# <div class="carousel-cell-image-wrapper annotation-container fixed-ratio-3-2">
# <picture>
# <source media="(min-width: 1200px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=90&amp;w=1400&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 992px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=80&amp;w=1000&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 768px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 768px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=70&amp;w=1125&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 768px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=75&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 320px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 320px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=70&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 320px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=70&amp;w=500&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 0px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 0px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=70&amp;w=480&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 0px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=70&amp;w=320&amp;cbr=1&amp;fit=max"/>
# <img alt="애플 비츠 바이 드레 파워비츠4 공식 발매 정보 및 가격, 비츠 바이 드레, 애플, 이어폰, 애플 이어폰, 블루투스 이어폰" class="carousel-cell-image" draggable="false" src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-03.jpg?q=75&amp;w=800&amp;cbr=1&amp;fit=max"/>
# </picture>
# </div>
# <span class="gallery-image-index"><span class="image-index">3 of 4</span><span class="sprite-gallery-expand" ga-event-action="clicks_fullscreen" ga-event-category="gallery post (article page)" ga-event-label="Clicks" ga-on="click"></span></span>
# <div class="gallery-meta-container credit-wrapper">
# <div class="spacer"></div>
# <div class="credit general-general">Beats</div>
# </div>
# </div>
# </div>
# <div class="carousel-cell landscape" data-gallery-index="4">
# <div class="carousel-cell-inner-wrapper">
# <div class="carousel-cell-image-wrapper annotation-container fixed-ratio-3-2">
# <picture>
# <source media="(min-width: 1200px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=90&amp;w=1400&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 992px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=80&amp;w=1000&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 768px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 768px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=70&amp;w=1125&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 768px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=75&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 320px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 320px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=70&amp;w=750&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 320px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=70&amp;w=500&amp;cbr=1&amp;fit=max"/>
# <source media="
#                                             (min-width: 0px) and (-webkit-min-device-pixel-ratio: 2),
#                                             (min-width: 0px) and (min-resolution: 192dpi)
#                                         " srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=70&amp;w=480&amp;cbr=1&amp;fit=max"/>
# <source media="(min-width: 0px)" srcset="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=70&amp;w=320&amp;cbr=1&amp;fit=max"/>
# <img alt="애플 비츠 바이 드레 파워비츠4 공식 발매 정보 및 가격, 비츠 바이 드레, 애플, 이어폰, 애플 이어폰, 블루투스 이어폰" class="carousel-cell-image" draggable="false" src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-beats-by-dre-powerbeats-4-releases-04.jpg?q=75&amp;w=800&amp;cbr=1&amp;fit=max"/>
# </picture>
# </div>
# <span class="gallery-image-index"><span class="image-index">4 of 4</span><span class="sprite-gallery-expand" ga-event-action="clicks_fullscreen" ga-event-category="gallery post (article page)" ga-event-label="Clicks" ga-on="click"></span></span>
# <div class="gallery-meta-container credit-wrapper">
# <div class="spacer"></div>
# <div class="credit">Beats</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="post-body-top-bar d-block d-lg-none" id="post-body-top-bar">
# <div class="row">
# <div class="post-body-top-bar-share-meta-container">
# <div class="post-body-top-bar-meta">
# <span class="post-body-top-bar-category">
# <a class="category category-tech" ga-event-action="clicks_category" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/tech" ga-on="click" href="https://hypebeast.kr/tech" title="전자">전자</a>
# </span>
# <span class="post-body-top-bar-published">
# <time class="timeago" datetime="2020-03-18T03:51:43Z">1 Hr ago</time>
# </span>
# </div>
# </div>
# <div class="post-body-top-bar-hype-comments-container d-none d-md-flex">
# </div>
# </div>
# </div>
# <div class="row post-body">
# <aside class="post-body-sidebar col-lg-4 d-none d-md-flex">
# <div class="post-body-sidebar-upper">
# <div class="post-body-sidebar-share d-none d-md-flex">
# <share-buttons :data='{"page":"article page","link":"https%3A%2F%2Fhypebeast.kr%2F2020%2F3%2Fapple-beats-by-dre-powerbeats-4-releases","name":"\uc560\ud50c, \ube44\uce20 \ubc14\uc774 \ub4dc\ub808 \ud30c\uc6cc\ube44\uce20 4 \uacf5\uc2dd \ubc1c\ub9e4 \uc815\ubcf4 \ubc0f \uac00\uaca9","image":{"url":"https:\/\/image-cdn.hypb.st\/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-powerbeats-4-releases-tw.jpg?w=960&amp;cbr=1&amp;q=90&amp;fit=max"}}'></share-buttons>
# </div>
# <hr class="sidebar-divider d-none d-lg-block"/>
# <div class="post-body-sidebar-category d-none d-lg-block">
# <a class="category category-tech" ga-event-action="clicks_category" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/tech" ga-on="click" href="https://hypebeast.kr/tech" title="전자">전자</a>
# </div>
# <div class="post-body-sidebar-published d-none d-lg-block">
# <time class="timeago" datetime="2020-03-18T03:51:43Z">1 Hr ago</time>
# </div>
# <div class="post-body-sidebar-author mt-1 mb-3 mt-lg-0 mb-lg-0">
# <span class="author-name">By <a class="article-author" ga-event-action="clicks_author" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/3/apple-beats-by-dre-powerbeats-4-releases" ga-on="click" href="https://hypebeast.kr/author/eunboshim" rel="author">Eunbo Shim</a></span>
# </div>
# </div>
# </aside>
# <article class="post-body-article col-lg-8">
# <div class="post-body-content">
# <p><a href="https://hypebeast.kr/search?s=%EC%95%A0%ED%94%8C">애플</a>과 <a href="https://hypebeast.kr/tags/beats-by-dre">비츠 바이 드레</a>의 스포츠 블루투스 이어폰 파워비츠 4의 공식 정보가 공개됐다. 지난 3월 10일, IT 매거진 &lt;윈퓨처&gt;는 파워비츠 4가 15시간의 배터리 수명, 5분 충전으로 60분 음악을 재생할 수 있는 고속 충전을 지원할 것이라고 <a href="https://hypebeast.com/2020/3/apple-powerbeats-4-specs-design-leaked-rumor">전했다</a>. 루머는 정확했다. 이어폰 바워비츠 4의 사용 가능 시간은 배터리 완전 충전 기준 15시간이며 고속 충전을 지원한다. 스포츠 블루투스 이어폰인 만큼 운동 시 흘리는 땀이나 약간의 물 튐을 방지할 수 있는  수준의 IPX4 방수 등급을 받았다. SoC(System-on-chip)는 비츠 솔로 프로와 <a href="https://hypebeast.kr/tags/airpod">에어팟</a> 2세대에 사용된 H1 칩이 탑재되어 기존 파워비츠 시리즈와 달리 시리 명령어를 지원한다. 오디오 공유 기능을 지원하여 두 세트의 비츠 헤드폰이나 에어팟을 아이폰에 연결해 친구와 함께 음악을 들을 수 있다. 파워비츠 4는 블랙, 화이트, 레드 세 가지의 컬러로 출시된다. 가격은 1십6만9천 원이며 출시일은 3월 19일로 예상된다.</p>
# <div class="show-article">
# <a class="show-article-btn btn btn-block" ga-event-action="click" ga-event-category="full article button" ga-on="click" href="#">
#                                                             더 보기
#                                                         </a>
# </div>
# </div>
# <footer>
# <div class="post-body-credentials">
# </div>
# <div class="post-body-content-tags">
# <div class="body">
# <a class="tag tag-apple" ga-event-action="clicks_tags" ga-event-category="article page" ga-event-label="https://hypebeast.kr/tags/apple" ga-on="click" href="https://hypebeast.kr/tags/apple" title="애플">애플</a><a class="tag tag-airpod" ga-event-action="clicks_tags" ga-event-category="article page" ga-event-label="https://hypebeast.kr/tags/airpod" ga-on="click" href="https://hypebeast.kr/tags/airpod" title="에어팟">에어팟</a><a class="tag tag-beats-by-dre" ga-event-action="clicks_tags" ga-event-category="article page" ga-event-label="https://hypebeast.kr/tags/beats-by-dre" ga-on="click" href="https://hypebeast.kr/tags/beats-by-dre" title="비츠 바이 드레">비츠 바이 드레</a>
# </div>
# </div>
# </footer>
# <div class="sponsored-content row">
# <div class="post-article adunit sticky-post" data-adunit="HB_KR_AFTERCONTENT" data-dimensions="1x1" data-sortable="false" data-targeting='{"HBSiteLoc":["ros","article"],"HBSiteCat":["tech","apple","airpod","beats-by-dre"],"HBSitePage":"0","HBSiteLang":"kr","country":"us","region":"amer","HBArticle":"265611","HBBlacklist":"0"}'></div>
# </div>
# </article>
# </div>
# <div class="post-footer row" id="post-footer">
# <div class="col-related-posts">
# <div class="post-footer-related-posts" ga-impression-event-action="impressions_related_post" ga-impression-event-category="article page" ga-impression-event-label="#" id="post-footer-related-posts">
# <h4 class="section-heading mt-2 mb-3">더 볼만한 기사</h4>
# <div class="post-footer-related-posts-container">
# <div class="post-box" data-permalink="https://hypebeast.kr/2020/3/apple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth" data-title="애플의 새로운 이어폰, 파워비츠 4 디자인 유출" ga-event-action="clicks_related_post" ga-event-category="article page" ga-event-label="https://hypebeast.kr/2020/3/apple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth" ga-on="click" id="post-263417"><div class="post-box-image-container fixed-ratio-3-2"><a class="thumbnail" ga-event-action="clicks_feature_image" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/3/apple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth" ga-on="click" href="https://hypebeast.kr/2020/3/apple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth" title="애플의 새로운 이어폰, 파워비츠 4 디자인 유출"><img alt="애플의 새로운 이어폰, 파워비츠 4 디자인 유출" class="img-fluid lazy-load" data-src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F03%2Fapple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth-2020-ft.jpg?fit=max&amp;cbr=1&amp;q=90&amp;w=750&amp;h=500"/></a></div><div class="post-box-content-container"><div class="post-box-content-title"><a class="title" ga-event-action="clicks_article_title" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/3/apple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth" ga-on="click" href="https://hypebeast.kr/2020/3/apple-powerbeats-4-specs-design-leaked-rumor-h1-bluetooth" title="애플의 새로운 이어폰, 파워비츠 4 디자인 유출"><h2><span>애플의 새로운 이어폰, 파워비츠 4 디자인 유출</span></h2></a></div></div></div>
# <div class="post-box" data-permalink="https://hypebeast.kr/2019/12/apple-airpods-stats-third-largest-product-2021-analysts" data-title="애플, 2019년 한 해 에어팟만 7조 원어치 판매" ga-event-action="clicks_related_post" ga-event-category="article page" ga-event-label="https://hypebeast.kr/2019/12/apple-airpods-stats-third-largest-product-2021-analysts" ga-on="click" id="post-244324"><div class="post-box-image-container fixed-ratio-3-2"><a class="thumbnail" ga-event-action="clicks_feature_image" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2019/12/apple-airpods-stats-third-largest-product-2021-analysts" ga-on="click" href="https://hypebeast.kr/2019/12/apple-airpods-stats-third-largest-product-2021-analysts" title="애플, 2019년 한 해 에어팟만 7조 원어치 판매"><img alt="애플, 2019년 한 해 에어팟만 7조 원어치 판매" class="img-fluid lazy-load" data-src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2019%2F12%2Fapple-airpods-stats-third-largest-product-2021-analysts-1.jpg?fit=max&amp;cbr=1&amp;q=90&amp;w=750&amp;h=500"/></a></div><div class="post-box-content-container"><div class="post-box-content-title"><a class="title" ga-event-action="clicks_article_title" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2019/12/apple-airpods-stats-third-largest-product-2021-analysts" ga-on="click" href="https://hypebeast.kr/2019/12/apple-airpods-stats-third-largest-product-2021-analysts" title="애플, 2019년 한 해 에어팟만 7조 원어치 판매"><h2><span>애플, 2019년 한 해 에어팟만 7조 원어치 판매</span></h2></a></div></div></div>
# <div class="post-box" data-permalink="https://hypebeast.kr/2020/1/red-apple-watch-release-spring-rumor" data-title="애플, 올 봄에 '레드 애플 워치' 선보일 전망이다" ga-event-action="clicks_related_post" ga-event-category="article page" ga-event-label="https://hypebeast.kr/2020/1/red-apple-watch-release-spring-rumor" ga-on="click" id="post-245469"><div class="post-box-image-container fixed-ratio-3-2"><a class="thumbnail" ga-event-action="clicks_feature_image" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/1/red-apple-watch-release-spring-rumor" ga-on="click" href="https://hypebeast.kr/2020/1/red-apple-watch-release-spring-rumor" title="애플, 올 봄에 '레드 애플 워치' 선보일 전망이다"><img alt="애플, 올 봄에 '레드 애플 워치' 선보일 전망이다" class="img-fluid lazy-load" data-src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F01%2Fred-apple-watch-release-spring-rumor-1.jpg?fit=max&amp;cbr=1&amp;q=90&amp;w=750&amp;h=500"/></a></div><div class="post-box-content-container"><div class="post-box-content-title"><a class="title" ga-event-action="clicks_article_title" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/1/red-apple-watch-release-spring-rumor" ga-on="click" href="https://hypebeast.kr/2020/1/red-apple-watch-release-spring-rumor" title="애플, 올 봄에 '레드 애플 워치' 선보일 전망이다"><h2><span>애플, 올 봄에 '레드 애플 워치' 선보일 전망이다</span></h2></a></div></div></div>
# <div class="post-box" data-permalink="https://hypebeast.kr/2020/2/apple-airpods-pro-lite-release-rumor-info" data-title="애플 에어팟 프로, 기존보다 저렴한 ‘라이트’ 출시된다?" ga-event-action="clicks_related_post" ga-event-category="article page" ga-event-label="https://hypebeast.kr/2020/2/apple-airpods-pro-lite-release-rumor-info" ga-on="click" id="post-256419"><div class="post-box-image-container fixed-ratio-3-2"><a class="thumbnail" ga-event-action="clicks_feature_image" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/2/apple-airpods-pro-lite-release-rumor-info" ga-on="click" href="https://hypebeast.kr/2020/2/apple-airpods-pro-lite-release-rumor-info" title="애플 에어팟 프로, 기존보다 저렴한 ‘라이트’ 출시된다?"><img alt="애플 에어팟 프로, 기존보다 저렴한 ‘라이트’ 출시된다?" class="img-fluid lazy-load" data-src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F02%2Fapple-airpods-pro-lite-release-rumor-info-ft.jpg?fit=max&amp;cbr=1&amp;q=90&amp;w=750&amp;h=500"/></a></div><div class="post-box-content-container"><div class="post-box-content-title"><a class="title" ga-event-action="clicks_article_title" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/2/apple-airpods-pro-lite-release-rumor-info" ga-on="click" href="https://hypebeast.kr/2020/2/apple-airpods-pro-lite-release-rumor-info" title="애플 에어팟 프로, 기존보다 저렴한 ‘라이트’ 출시된다?"><h2><span>애플 에어팟 프로, 기존보다 저렴한 ‘라이트’ 출시된다?</span></h2></a></div></div></div>
# <div class="post-box" data-permalink="https://hypebeast.kr/2020/2/apple-airpods-x-generation-headphone-iphone-ipad-release-rumor-info" data-title="애플 곧 새로운 헤드폰, 아이폰, 아이패드를 출시한다?" ga-event-action="clicks_related_post" ga-event-category="article page" ga-event-label="https://hypebeast.kr/2020/2/apple-airpods-x-generation-headphone-iphone-ipad-release-rumor-info" ga-on="click" id="post-259413"><div class="post-box-image-container fixed-ratio-3-2"><a class="thumbnail" ga-event-action="clicks_feature_image" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/2/apple-airpods-x-generation-headphone-iphone-ipad-release-rumor-info" ga-on="click" href="https://hypebeast.kr/2020/2/apple-airpods-x-generation-headphone-iphone-ipad-release-rumor-info" title="애플 곧 새로운 헤드폰, 아이폰, 아이패드를 출시한다?"><img alt="애플 곧 새로운 헤드폰, 아이폰, 아이패드를 출시한다?" class="img-fluid lazy-load" data-src="https://image-cdn.hypb.st/https%3A%2F%2Fkr.hypebeast.com%2Ffiles%2F2020%2F02%2Fapple-airpods-x-generation-release-rumor-info-001.jpg?fit=max&amp;cbr=1&amp;q=90&amp;w=750&amp;h=500"/></a></div><div class="post-box-content-container"><div class="post-box-content-title"><a class="title" ga-event-action="clicks_article_title" ga-event-category="post box clicks" ga-event-label="https://hypebeast.kr/2020/2/apple-airpods-x-generation-headphone-iphone-ipad-release-rumor-info" ga-on="click" href="https://hypebeast.kr/2020/2/apple-airpods-x-generation-headphone-iphone-ipad-release-rumor-info" title="애플 곧 새로운 헤드폰, 아이폰, 아이패드를 출시한다?"><h2><span>애플 곧 새로운 헤드폰, 아이폰, 아이패드를 출시한다?</span></h2></a></div></div></div>
# ...
# </div>
# <div class="mobile-menu-social">
# <ul class="nav"><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="https://www.facebook.com/hypebeastkr" ga-on="click"><a class="facebook social" href="https://www.facebook.com/hypebeastkr" rel="noopener" target="_blank"><span class="sprite sprite-social-facebook-black-32"></span></a></li><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="https://twitter.com/hypebeastkr" ga-on="click"><a class="twitter social" href="https://twitter.com/hypebeastkr" rel="noopener" target="_blank" title="Twitter"><span class="sprite sprite-social-twitter-black-32"></span></a></li><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="https://instagram.com/hypebeastkr" ga-on="click"><a class="instagram social" href="https://instagram.com/hypebeastkr" rel="noopener" target="_blank" title="Instagram"><span class="sprite sprite-social-instagram-black-32"></span></a></li><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="https://story.kakao.com/ch/hypebeast" ga-on="click"><a class="kakao social" href="https://story.kakao.com/ch/hypebeast" rel="noopener" target="_blank" title="Kakao"><span class="sprite sprite-social-kakao-story-black-32"></span></a></li><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="http://post.naver.com/hypebeastkr" ga-on="click"><a class="naver social" href="http://post.naver.com/hypebeastkr" rel="noopener" target="_blank" title="Naver"><span class="sprite sprite-social-naver-black-32"></span></a></li><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="https://www.youtube.com/channel/UCjM88nGPxVMLNm1ctUTROmA" ga-on="click"><a class="youtube social" href="https://www.youtube.com/channel/UCjM88nGPxVMLNm1ctUTROmA" rel="noopener" target="_blank" title="Youtube"><span class="sprite sprite-social-youtube-black-32"></span></a></li><li ga-event-action="clicks_socials" ga-event-category="burger menu" ga-event-label="https://feedly.com/i/subscription/feed/" ga-on="click"><a class="feedly social" href="https://feedly.com/i/subscription/feed/https://hypebeast.kr/feed" rel="noopener" target="_blank" title="Feedly"><span class="sprite sprite-social-rss-32"></span></a></li></ul>
# </div>
# <div class="mobile-menu-email">
# <form action="https://hypebeast.kr/newsletter" class="header-newsletter-signup-form" method="POST" rel="noopener">
# <div class="input-group">
# <input class="newsletter-email" name="email" placeholder="정기 구독하기" required="" size="16" type="email"/>
# <input name="source" type="hidden" value="Newsletter Main Nav"/>
# <button class="input-group-btn" ga-event-action="clicks_newsletter_signup_burger" ga-event-category="burger menu (mobile only)" ga-event-label="Clicks" ga-on="click" type="submit">구독하기</button>
# </div>
# </form>
# </div>
# <div class="mobile-menu-download-page d-flex">
# <ul class="app-icons"><li ga-event-action="clicks_app" ga-event-category="burger menu" ga-event-label="https://hypebeast.kr/app/" ga-on="click"><a class="" href="https://hypebeast.kr/app/" target="_blank"><span class="sprite sprite-app-store-kr"></span></a></li><li ga-event-action="clicks_app" ga-event-category="burger menu" ga-event-label="https://hypebeast.kr/app/" ga-on="click"><a class="" href="https://hypebeast.kr/app/" target="_blank"><span class="sprite sprite-google-play-kr"></span></a></li></ul>
# </div>
# <div class="mobile-dark-mode">
# <div class="mobile-dark-mode-wrapper">
# <div class="sprite sprite-nav-dark-outline"></div>
# <div class="sprite sprite-nav-dark"></div>
# <span class="menu-title">Dark Mode</span>
# <span class="dark-mode-toggle-switch">
# <label class="switch">
# <input type="checkbox"/>
# <span class="slider round"></span>
# </label>
# </span>
# </div>
# </div>
# <div class="mobile-menu-other">
# <div class="mobile-dropdown-toggle">
# <div class="dropdown-menu-sprite sprite-hamburger-more"></div>
# <span class="dropdown-menu-title">More</span>
# <span class="dropdown-sprite sprite sprite-arrow-down align-bottom"></span>
# </div><ul class="list-unstyled mobile-menu-dropdown"><li ga-event-action="clicks_101media" ga-event-category="burger menu" ga-event-label="/about" ga-on="click"><a href="/about">회사소개</a></li><li ga-event-action="clicks_101media" ga-event-category="burger menu" ga-event-label="/team" ga-on="click"><a href="/team">Our Team</a></li><li ga-event-action="clicks_101media" ga-event-category="burger menu" ga-event-label="/contact" ga-on="click"><a href="/contact">Contact Us</a></li><li ga-event-action="clicks_101media" ga-event-category="burger menu" ga-event-label="/advertise" ga-on="click"><a href="/advertise">광고</a></li><li ga-event-action="clicks_101media" ga-event-category="burger menu" ga-event-label="/gdpr" ga-on="click"><a href="/gdpr">GDPR</a></li><li><a href="https://hypebeast.xyz/investor-relations">기업설명활동</a></li></ul>
# </div>
# <div class="mobile-menu-elsewhere">
# <div class="mobile-dropdown-toggle">
# <div class="dropdown-menu-sprite sprite-hamburger-elsewhere"></div>
# <span class="dropdown-menu-title">Elsewhere</span>
# <span class="dropdown-sprite sprite sprite-arrow-down align-bottom"></span>
# </div><ul class="list-unstyled mobile-menu-dropdown"><li><a class="hypebae" href="https://hypebae.com/" rel="noopener" target="_blank" title="HYPEBAE">
#                     HYPEBAE
#                 </a></li><li><a class="hbx" href="https://hbx.com?utm_source=hypebeast.com&amp;utm_medium=referral&amp;utm_campaign=hypebeast.com_top_area_button" rel="noopener" target="_blank" title="HBX">
#                     HBX
#                 </a></li></ul>
# </div>
# <div class="mobile-menu-copyright">
# <div>2020 Hypebeast Limited. All Rights Reserved.</div>
# <div class="footer-links">
# <span><a href="https://hypebeast.kr/terms">이용약관</a></span>
# <span><a href="https://hypebeast.kr/privacy">개인정보</a></span>
# </div>
# <div>HYPEBEAST® is a registered trademark of Hypebeast Hong Kong Ltd.</div>
# </div>
# </div>
# </div>
# <div id="header-search-container">
# <div class="container-fluid" id="header-search">
# <form action="/search">
# <input autocomplete="off" id="header-search-input" name="s" placeholder="무엇을 찾으시는 건가요?" type="text"/>
# <button type="submit">
# <span class="sprite sprite-search"></span>
# </button>
# <div class="close-btn">
# <span class="sprite sprite-close"></span>
# </div>
# </form>
# <div class="hide" data-suggestion-url="https://hypebeast.kr/search-suggest" id="header-search-trending">
# <h4 id="search-suggestion-title">Trending</h4>
# <ul class="list-unstyled" id="search-suggestions">
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=supreme" ga-on="click" href="https://hypebeast.kr/search?s=supreme">Supreme</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=adidas" ga-on="click" href="https://hypebeast.kr/search?s=adidas">Adidas</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=uniqlo" ga-on="click" href="https://hypebeast.kr/search?s=uniqlo">UNIQLO</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=nike" ga-on="click" href="https://hypebeast.kr/search?s=nike">Nike</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=palace" ga-on="click" href="https://hypebeast.kr/search?s=palace">Palace</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=puma" ga-on="click" href="https://hypebeast.kr/search?s=puma">Puma</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=converse" ga-on="click" href="https://hypebeast.kr/search?s=converse">Converse</a></li>
# <li><a ga-event-action="clicks_trending_search_terms" ga-event-category="search" ga-event-label="https://hypebeast.kr/search?s=noah" ga-on="click" href="https://hypebeast.kr/search?s=noah">Noah</a></li>
# </ul>
# </div>
# </div>
# </div>
# <post-sticky-share-bar></post-sticky-share-bar>
# <div class="showAd" id="bottomAd" style="font-size: 2px;"> </div>
# </div>
# <div class="modal fade weixin_popup" id="weixin-modal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <img src="https://static.hypebeast.com/images/hypebeast/wechat-qr-code.png?j89547yv"/>
# </div>
# <div class="modal-footer">
# </div>
# </div>
# </div>
# </div>
# <div id="newsletter-popup-fixed">
# <div class="modal-close-btn">
# <img src="https://static.hypebeast.com/images/hypebeast/icons/close_white@2x.png?j89547yv">
# </img></div>
# <div class="impression-tracker" ga-impression-event-action="impressions_newsletter" ga-impression-event-category="newsletter/ app popup" ga-impression-event-label="#" id="editorial-newsletter">
# <div class="wrapper">
# <header>
# <span>뉴스레터 구독 신청</span>
# </header>
# <p class="update"></p>
# <p class="intro">뉴스레터 구독 신청으로 &lt;하입비스트&gt;가 제공하는 특집 인터뷰와 각종 발매 소식 그리고 최신 트렌드의 현황을 모두 누리세요.</p>
# <form action="//hypebeast.kr/newsletter" class="newsletter-signup-form" data-ga-action="" id="sidebar-newsletter-form" method="POST" rel="noopener">
# <div class="input-group">
# <input class="form-control newsletter-email" name="email" placeholder="이메일 주소 입력" required="required" size="16" type="email">
# <input name="source" type="hidden" value="Newsletter Popup"/>
# <span class="input-group-btn"> <button class="btn btn-default" ga-event-action="clicks_popup_signup" ga-event-category="newsletter/ app popup" ga-event-label="#" ga-on="click" type="submit">
#                     구독하기
#                 </button>
# </span>
# </input></div>
# </form>
# <div class="agreement-wrapper">
# <span>본 뉴스레터 구독 신청에 따라 자사의 <a href="/privacy" target="_blank">개인정보수집 </a> 관련 <a href="/terms" target="_blank">이용약관</a>에 동의한 것으로 간주됩니다.</span>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" data-app-cookie="app_popup_hypebeast_kr" data-newsletter-cookie="newsletter_popup_hypebeast_kr" id="newsletter-popup" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content app-modal">
# <div class="row">
# <div class="modal-close-btn">
# <img src="https://static.hypebeast.com/images/hypebeast/icons/close_white@2x.png?j89547yv">
# </img></div>
# <div class="col-12 register-form">
# <div class="section impression-tracker active" ga-impression-event-action="impressions_app" ga-impression-event-category="newsletter/ app popup" ga-impression-event-label="#" id="editorial-app">
# <div class="wrapper">
# <header>
# <div class="app-icon">
# <img alt="HYPEBEAST" class="logo" src="https://static.hypebeast.com/images/hypebeast/app/app-icon-with-border.png?j89547yv"/>
# </div>
# <div class="hypebeast-icon">
# <img alt="HYPEBEAST" class="logo" src="https://static.hypebeast.com/images/hypebeast/logo-white.png?j89547yv"/>
# <span>아이폰, 아이패드 그리고 안드로이드폰 모두 무료</span>
# </div>
# </header>
# <p class="message">
#                                     본 애플리케이션을 통해 하입비스트가 전하는 속보, 실시간 스토리, 정제된 기사 등을 마음껏 누려보세요.
#                                 </p>
# <div class="app-stores">
# <a class="download" ga-event-action="clicks_app" ga-event-category="newsletter/ app popup" ga-event-label="https://click.google-analytics.com/redirect?tid=UA-546583-25&amp;aid=com.hypebeast.app&amp;cs=hypebeast&amp;cm=web&amp;cn=app_page&amp;url=https%3A%2F%2Fitunes.apple.com%2Fapp%2Fhypebeast%2Fid986768161%3Fpt%3D2303216%26mt%3D8%26ct%3DApp%2520Page" ga-on="click" href="https://click.google-analytics.com/redirect?tid=UA-546583-25&amp;aid=com.hypebeast.app&amp;cs=hypebeast&amp;cm=web&amp;cn=app_page&amp;url=https%3A%2F%2Fitunes.apple.com%2Fapp%2Fhypebeast%2Fid986768161%3Fpt%3D2303216%26mt%3D8%26ct%3DApp%2520Page" target="_blank">
# <img src="https://static.hypebeast.com/images/app/app-store-kr@2x.png?j89547yv"/>
# </a>
# <a class="download" ga-event-action="clicks_app" ga-event-category="newsletter/ app popup" ga-event-label="https://play.google.com/store/apps/details?id=com.hypebeast.editorial&amp;referrer=utm_source%3Dhypebeast%26utm_medium%3Dweb%26utm_campaign%3Dapp_page" ga-on="click" href="https://play.google.com/store/apps/details?id=com.hypebeast.editorial&amp;referrer=utm_source%3Dhypebeast%26utm_medium%3Dweb%26utm_campaign%3Dapp_page" target="_blank">
# <img src="https://static.hypebeast.com/images/app/google-play-kr@2x.png?j89547yv"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="impression-tracker" ga-impression-event-action="impressions_adblockmessage" ga-impression-event-category="ad block message" ga-impression-event-label="#" id="ad-blocker-popup">
# <div class="ad-blocker-container">
# <div class="inner-content">
# <header>
# <div class="spacer"></div>
# <div class="logo-container">
# <img alt="HYPEBEAST" class="logo" src="https://static.hypebeast.com/images/hypebeast2018/hypebeast-logo.svg?j89547yv">
# </img></div>
# <div class="close-btn-container">
# <button class="btn btn-link original" ga-event-action="clicks_x" ga-event-category="ad block message" ga-event-label="#" ga-on="click">
# <img alt="close" src="https://static.hypebeast.com/images/hypebeast/icons/close_white@2x.png?j89547yv">
# </img></button>
# </div>
# </header>
# <main>
# <h3 class="original">더 나은 서비스를 제공할 수 있도록 협조 부탁 드립니다</h3>
# <h3 class="enforce">We noticed you are using an ad-blocker</h3>
# <p class="content-p">
#                     &lt;하입비스트&gt;가 제공하는 광고 수신에 동의해주셔서 감사합니다. &lt;하입비스트&gt;는 여러분의 관심사와 최신 트렌드에 걸맞은 광고를 제공합니다. 광고차단기(애드블록)의 ‘화이트 리스트'에 &lt;하입비스트&gt;를 추가하면 사이트에 머무는 동안 계속해서 광고가 제공되는 점 참고 부탁 드립니다.
#                 </p>
# <p class="link-p">
# <a class="original" ga-event-action="clicks_learn_more" ga-event-category="ad block message" ga-event-label="#" ga-on="click" href="https://hypebeast.kr/allow-ads" target="_blank">더 알아보기 ›</a>
# <a class="enforce" ga-event-action="clicks_learn_more" ga-event-category="ad block message" ga-event-label="#" ga-on="click" href="https://hypebeast.kr/allow-ads" target="_blank">화이트리스트'에 추가하기 ›</a>
# </p>
# </main>
# <footer>
# <a class="btn btn-link original" ga-event-action="clicks_add_to_whitelist" ga-event-category="ad block message" ga-event-label="#" ga-on="click" href="https://hypebeast.kr/allow-ads" target="_blank">
#                     화이트리스트'에 추가하기
#                 </a>
# <a class="btn btn-link enforce turned-off" ga-event-action="clicks_add_to_whitelist" ga-event-category="ad block message" ga-event-label="#" ga-on="click" href="#">
#                     I’ve Turned Off My Ad Blocker
#                 </a>
# </footer>
# </div>
# </div>
# </div>
# <div class="adunit background" data-adunit="Hypebeast_KR_ROS_Background" data-outofpage="true" data-targeting='{"HBSiteLoc":["ros","article"],"HBSiteCat":["tech","apple","airpod","beats-by-dre"],"HBSitePage":"0","HBSiteLang":"kr","country":"us","region":"amer","HBArticle":"265611","HBBlacklist":"0"}'>
# </div>
# <script src="https://static.hypebeast.com/dist/hypebeast2018/scripts/commons.js?j89547yv" type="application/javascript"></script>
# <script src="https://static.hypebeast.com/dist/hypebeast2018/scripts/main.js?j89547yv" type="application/javascript"></script>
# <script src="https://static.hypebeast.com/dist/hypebeast2018/scripts/post.js?j89547yv" type="application/javascript"></script>
# </body>
# </html>

# %%
content = dom.select_one('.row p').text.replace("\xa0", "")
content
# Out:
# '애플과 비츠 바이 드레의 스포츠 블루투스 이어폰 파워비츠 4의 공식 정보가 공개됐다. 지난 3월 10일, IT 매거진 <윈퓨처>는 파워비츠 4가 15시간의 배터리 수명, 5분 충전으로 60분 음악을 재생할 수 있는 고속 충전을 지원할 것이라고 전했다. 루머는 정확했다. 이어폰 바워비츠 4의 사용 가능 시간은 배터리 완전 충전 기준 15시간이며 고속 충전을 지원한다. 스포츠 블루투스 이어폰인 만큼 운동 시 흘리는 땀이나 약간의 물 튐을 방지할 수 있는 수준의 IPX4 방수 등급을 받았다. SoC(System-on-chip)는 비츠 솔로 프로와 에어팟 2세대에 사용된 H1 칩이 탑재되어 기존 파워비츠 시리즈와 달리 시리 명령어를 지원한다. 오디오 공유 기능을 지원하여 두 세트의 비츠 헤드폰이나 에어팟을 아이폰에 연결해 친구와 함께 음악을 들을 수 있다. 파워비츠 4는 블랙, 화이트, 레드 세 가지의 컬러로 출시된다. 가격은 1십6만9천 원이며 출시일은 3월 19일로 예상된다.'

# %% [markdown]
# ### content 데이터 함수로 만들기

# %%
def get_content(link):
    response = requests.get(link)
    dom = BeautifulSoup(response.content, "html.parser")
    return dom.select_one('.row p').text.strip().replace("\xa0", "")

# %%
hb_df["content"] = hb_df["link"].apply(get_content)
hb_df.tail(2)
# Out:
#   category                             title                       summary  \
# 8       패션  바빌론 LA 2020 봄 컬렉션, 두 번째 드롭 룩북 공개  슈프림, 팔라스를 이을 차세대 스트리트웨어 브랜드.
# 9       신발   릭 오웬스, 네 종류의 메가투스 부츠 출시 및 구매 좌표        복잡한 슈 레이스와 간결한 부츠의 대조.
#
#     author                                               link        date  \
# 8  HB Team  https://hypebeast.kr/2020/3/babylon-la-spring-...  19 Hrs ago
# 9  HB Team  https://hypebeast.kr/2020/3/rick-owens-black-m...  21 Hrs ago
#
#                                              content
# 8  리 스필만과 가렛 스티븐슨의 스케이트보드 기반스트리트웨어 브랜드, 바빌론 LA가 2...
# 9  릭 오웬스가 네 종류의 새로운 메가투스 부츠를 출시했다. 가장 먼저 눈에 띄는 제품...

# %%
hb_df.loc[0, "content"]
# Out:
# '디올과조던 브랜드의 협업 스니커, 에어 조던 1 하이 OG 디올의 발매일이 공식적으로 연기됐다. 나이키는 3월 17일, 브랜드 뉴스 채널을 통해 ‘공공단체의 권고에 따라, 모두의 안전을 보장하기 위하여 에어 디올 캡슐 컬렉션의 발매를 연기하기로 결정했다”라고 전했다.코로나19에 대한 직접적인 언급은 보도자료에 없었지만, 이번 발매 연기는최근 코로나19가 감염병 최고 경고 등급인 팬데믹으로 격상되면서 결정된 것으로 보인다.'

# %%
class Hypebeast:
    
    def __init__(self):
        self.basic_url = "https://hypebeast.kr" 
    
    # link를 받아서 content를 추가해주는 함수    
    def get_content(self, link):
        response = requests.get(link)
        dom = BeautifulSoup(response.content, "html.parser")
        return dom.select_one('.row p').text.strip().replace("\xa0", "")
        
    def one_page(self, page):
        elements = []
        for page in range(page, page * 20):
            print("Crawling : {}".format(page))
            url = "https://hypebeast.kr/page/{}?after=".format(page)
            response = requests.get(url)
            dom = BeautifulSoup(response.content, "html.parser")
            elements = elements + dom.select(".posts>div>.post-box-content-container")
        
        datas = []
        for element in elements :
            try:
                category = element.select_one('.post-box-content-categories> a').text
            except:
                category = "-"
            try:
                title = element.select_one('.post-box-content-title > a').text
            except:
                title = "-"
            try:
                summary = element.select_one('.post-box-content-excerpt').text.strip()
            except:
                summary = "-"
            try:
                author = element.select_one('.author-name > a').text
            except:
                author = "-"
            try:
                link = element.select_one('.post-box-content-title > a').get("href")
            except:
                link = "-"
            try:
                date = element.select_one('.time > time').text
            except:
                date = "-"

            data = ({
                "category" : category,
                "title" : title,
                "summary" : summary,
                "author" : author,
                "link" : link,
                "date" : date,
            })
            
            datas.append(data)
    
        hb_df = pd.DataFrame(datas)
        hb_df["content"] = hb_df["link"].apply(self.get_content)
        
        return hb_df

# %%
hypebeast = Hypebeast()

# %%
one_page_df = hypebeast.one_page(1)
one_page_df.tail()
# Out:
# Crawling : 1
# Crawling : 2
# Crawling : 3
# Crawling : 4
# Crawling : 5
# Crawling : 6
# Crawling : 7
# Crawling : 8
# Crawling : 9
# Crawling : 10
# Crawling : 11
# Crawling : 12
# Crawling : 13
# Crawling : 14
# Crawling : 15
# Crawling : 16
# Crawling : 17
# Crawling : 18
# Crawling : 19
#     category                                      title  \
# 185       신발            박스 로고 에어 포스 1 로우, 슈프림 공식 출시일 발표
# 186       패션          나이키, 코로나19 확산 우려에 오리건 본사 건물 폐쇄 조치
# 187       패션       성별의 경계를 지운, 톰 브라운 2020 FW 컬렉션 런웨이 무대
# 188       패션         진귀한 보석을 휘감은, 셀린 2020 FW 컬렉션 런웨이 현장
# 189       패션  스마일리 페이스가 렌즈에? 차이나타운 마켓 x 아킬라 선글라스 협업 컬렉션
#
#                        summary            author  \
# 185                   출시는 이번주.        Eunbo Shim
# 186              “확실한 예방을 위해.”     Yonghwan Choi
# 187          노아의 방주에서 영감을 받았다?       Hyeonuk Joo
# 188  스페인 조각가, 세자르 만리케의 유산과 함께.  Seung Hoon Jeong
# 189        요즘 같은 때, 눈이라도 웃어야지.     Seung Ho Jang
#
#                                                   link         date  \
# 185  https://hypebeast.kr/2020/3/supreme-nike-airfo...  Mar 2, 2020
# 186  https://hypebeast.kr/2020/3/nike-closure-coron...  Mar 2, 2020
# 187  https://hypebeast.kr/2020/3/thom-browne-fall-w...  Mar 2, 2020
# 188  https://hypebeast.kr/2020/3/celine-fall-winter...  Mar 2, 2020
# 189  https://hypebeast.kr/2020/3/chinatown-market-a...  Mar 2, 2020
#
#                                                content
# 185  슈프림과 나이키의 협업 박스 로고 에어 포스 1 로우의 출시일이 확정됐다. 나이키 ...
# 186  미국에서도 코로나19로 인한 첫 사망자가 발생하며 전염에 대한 염려가 커지는 와중,...
# 187  톰 브라운이 파리 패션위크에서 독특한 콘셉트의 런웨이 무대를 선보여 화제다. 톰 브...
# 188  에디 슬리먼이 이끌고 있는 셀린의 2020 가을, 겨울 컬렉션이 공개됐다. 파리 패...
# 189  차이나타운 마켓이 아이웨어 브랜드 아킬라와 손잡고 선글라스 컬렉션을 출시했다. ‘에...

# %%
one_page_df.describe()
# Out:
#        category                           title  \
# count       190                             190
# unique       11                             190
# top          패션  호카 오네 오네가 선보이는 첫 의류 및 액세서리 컬렉션
# freq         72                               1
#
#                                  summary       author  \
# count                                190          190
# unique                               190            8
# top     무선 이어폰을 샀는데 줄을 연결해야 하는 아이러니한 상황.  Hyeonuk Joo
# freq                                   1           47
#
#                                                      link          date  \
# count                                                 190           190
# unique                                                190            24
# top     https://hypebeast.kr/2020/3/bentley-mulliner-b...  Mar 16, 2020
# freq                                                    1            18
#
#        content
# count      190
# unique     189
# top
# freq         2

# %% [markdown]
# ### Hypebeast를 파일로 저장

# %%
# %%writefile hypebeast.py
import pandas as pd
import requests
from bs4 import BeautifulSoup

class Hypebeast:
    
    def __init__(self):
        self.basic_url = "https://hypebeast.kr" 
    
    # link를 받아서 content를 추가해주는 함수    
    def get_content(self, link):
        response = requests.get(link)
        dom = BeautifulSoup(response.content, "html.parser")
        return dom.select_one('.row p').text.strip().replace("\xa0", "")
    
    # page 입력 함수    
    def one_page(self, page):
        elements = []
        for page in range(page, page * 20):
            print("Crawling : {} page..".format(page))
            url = "https://hypebeast.kr/page/{}?after=".format(page)
            response = requests.get(url)
            dom = BeautifulSoup(response.content, "html.parser")
            elements = elements + dom.select(".posts>div>.post-box-content-container")
        
        # Css Select로 파싱할 때 해당 html이 없는 경우는 예외 처리 해주는 함수
        datas = []
        for element in elements :
            try:
                category = element.select_one('.post-box-content-categories> a').text
            except:
                category = "-"
            try:
                title = element.select_one('.post-box-content-title > a').text
            except:
                title = "-"
            try:
                summary = element.select_one('.post-box-content-excerpt').text.strip()
            except:
                summary = "-"
            try:
                author = element.select_one('.author-name > a').text
            except:
                author = "-"
            try:
                link = element.select_one('.post-box-content-title > a').get("href")
            except:
                link = "-"
            try:
                date = element.select_one('.time > time').text
            except:
                date = "-"

            data = ({
                "category" : category,
                "title" : title,
                "summary" : summary,
                "author" : author,
                "link" : link,
                "date" : date,
            })
            
            datas.append(data)
    
        hb_df = pd.DataFrame(datas)
        hb_df["content"] = hb_df["link"].apply(self.get_content)
        
        return hb_df
# Out:
# Overwriting hypebeast.py
